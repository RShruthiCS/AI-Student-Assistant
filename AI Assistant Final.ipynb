# %%
# !pip install unstructured pdf2image pytesseract

# %%
# !brew install poppler
# !brew install tesseract

# %%
# !pip install pdfminer.six

# %%
from unstructured.partition.pdf import partition_pdf

elements = partition_pdf("/Users/shruthiraghavan/Desktop/CS 131 notes/04-25su-cs131-permissions_processes.pdf", strategy="hi_res")
print(elements[0].text)

# %%
# !pip install pi-heif

# %%
from unstructured.partition.pdf import partition_pdf

elements = partition_pdf("/Users/shruthiraghavan/Desktop/CS 131 notes/04-25su-cs131-permissions_processes.pdf", strategy="hi_res")
print(elements[0].text)

# %%
# !pip install unstructured-inference

# %%
from unstructured.partition.pdf import partition_pdf

elements = partition_pdf("/Users/shruthiraghavan/Desktop/CS 131 notes/04-25su-cs131-permissions_processes.pdf", strategy="hi_res")
print(elements[0].text)

# %%
# !pip install unstructured[pytesseract]

# %%
# !pip install "unstructured[pytesseract]"

# %%
from unstructured.partition.pdf import partition_pdf

elements = partition_pdf(
    "/Users/shruthiraghavan/Desktop/CS 131 notes/04-25su-cs131-permissions_processes.pdf",
    strategy="hi_res"
)

print(elements[0].text)

# %%
# !pip install unstructured_pytesseract

# %%
from unstructured.partition.pdf import partition_pdf

elements = partition_pdf(
    "/Users/shruthiraghavan/Desktop/CS 131 notes/04-25su-cs131-permissions_processes.pdf",
    strategy="hi_res"
)

print(elements[0].text)

# %%
from langchain.schema import Document

documents = [Document(page_content=el.text) for el in elements]

print(f"✅ Converted {len(documents)} elements to LangChain documents.")
print(documents[0].page_content)

# %%
from langchain.text_splitter import CharacterTextSplitter

splitter = CharacterTextSplitter(chunk_size=500, chunk_overlap=50)
docs = splitter.split_documents(documents)

print(f"✅ Split into {len(docs)} chunks.")

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma

embedding = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

vectordb = Chroma.from_documents(
    docs,
    embedding=embedding,
    persist_directory="./chroma_db"
)

print("✅ Stored embeddings in ChromaDB.")

# %%
# !pip install sentence-transformers

# %%
# !pip install -U sentence-transformers

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma

embedding = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

vectordb = Chroma.from_documents(
    docs,
    embedding=embedding,
    persist_directory="./chroma_db"
)

print("✅ Stored embeddings in ChromaDB.")

# %%
# !pip install sentence-transformers --quiet

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma

embedding = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

vectordb = Chroma.from_documents(
    docs,
    embedding=embedding,
    persist_directory="./chroma_db"
)

print("✅ Stored embeddings in ChromaDB.")

# %%
import sys
print(sys.executable)

# %%
# !/Users/shruthiraghavan/anaconda3/bin/python -m pip install sentence-transformers

# %%
import sentence_transformers
print("✅ sentence-transformers is working!")

# %%
# !pip install -U transformers

# %%
import sentence_transformers
print("✅ sentence-transformers is working!")

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma

embedding = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

vectordb = Chroma.from_documents(
    docs,  # make sure `docs` contains your split OCR chunks
    embedding=embedding,
    persist_directory="./chroma_db"
)

print("✅ Stored embeddings in ChromaDB.")

# %%
from langchain.text_splitter import CharacterTextSplitter

splitter = CharacterTextSplitter(chunk_size=500, chunk_overlap=50)
docs = splitter.split_documents(documents)  # <- this creates the variable you're missing

print(f"✅ Split into {len(docs)} chunks.")

# %%
from langchain.schema import Document

# Convert OCR output into LangChain documents
documents = [Document(page_content=el.text) for el in elements]

print(f"✅ Converted {len(documents)} elements to LangChain documents.")

# %%
from unstructured.partition.pdf import partition_pdf

elements = partition_pdf(
    "/Users/shruthiraghavan/Desktop/CS 131 notes/04-25su-cs131-permissions_processes.pdf",
    strategy="hi_res"
)

# %%
from langchain.schema import Document

documents = [Document(page_content=el.text) for el in elements]

print(f"✅ Converted {len(documents)} elements to LangChain documents.")

# %%
from langchain.text_splitter import CharacterTextSplitter

splitter = CharacterTextSplitter(chunk_size=500, chunk_overlap=50)
docs = splitter.split_documents(documents)

print(f"✅ Split into {len(docs)} chunks.")

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma

embedding = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

vectordb = Chroma.from_documents(
    docs,
    embedding=embedding,
    persist_directory="./chroma_db"
)

print("✅ Stored embeddings in ChromaDB.")

# %%
from langchain_community.llms import Ollama
from langchain.chains import RetrievalQA

llm = Ollama(model="llama2")  # Make sure Ollama is running in background

qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=vectordb.as_retriever()
)

response = qa_chain.run("What is chmod used for?")
print(response)

# %%
from huggingface_hub import snapshot_download

snapshot_download("meta-llama/Llama-2-7b-chat-hf", use_auth_token=True)

# %%
# !pip install langchain-community

# %%
from langchain_community.llms import Ollama
from langchain.chains import RetrievalQA

# Use the local Ollama model
llm = Ollama(model="llama2")  # Or "mistral", "codellama", etc.

# Connect it with your ChromaDB retriever
qa_chain = RetrievalQA.from_chain_type(llm=llm, retriever=vectordb.as_retriever())

# Ask a question
response = qa_chain.run("What does chmod do in Linux?")
print("🤖", response)
